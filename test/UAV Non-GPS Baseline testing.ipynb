# %% [markdown]
# # Small sample of the training dataset

# %%
import sys
from pathlib import Path

# Add project root so we can import baseline
_root = Path.cwd().parent if Path.cwd().name == "test" else Path.cwd()
sys.path.insert(0, str(_root))

from baseline import test
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[6], line 8
#       5 _root = Path.cwd().parent if Path.cwd().name == "test" else Path.cwd()
#       6 sys.path.insert(0, str(_root))
# ----> 8 from baseline import test
#
# File ~/ayai/UAV/denseUAV_baseline/baseline/test.py:44
#      42 import yaml
#      43 import math
# ---> 44 from tool.utils import load_network
#      45 from tqdm import tqdm
#      46 import warnings
#
# ModuleNotFoundError: No module named 'tool'
